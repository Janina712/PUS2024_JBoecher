# %% [markdown]
# <a href="https://colab.research.google.com/github/Janina712/PUS2024_JBoecher/blob/main/HW1/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **0. imports**

# %%
import pandas as pd

# %% [markdown]
# **1. load data**

# %%
pparks = pd.read_csv("http://data-phl.opendata.arcgis.com/datasets/d52445160ab14380a673e5849203eb64_0.csv")

# %% [markdown]
# **2. get descriptive stats**

# %%
# summary
pparks.describe()
# Out:
#         OBJECTID  DPP_ASSET_ID      ZIP_CODE      ACREAGE   Shape__Area  \
# count  507.00000    507.000000    507.000000   507.000000  5.070000e+02
# mean   254.00000   2526.244576  19093.654832    20.000921  1.381845e+05
# std    146.50256   8765.140751    849.765381   111.843891  7.730881e+05
# min      1.00000      0.000000      0.000000     0.019246  1.327734e+02
# 25%    127.50000    829.500000  19122.000000     0.878760  6.056152e+03
# 50%    254.00000   1853.000000  19132.000000     3.600784  2.489234e+04
# 75%    380.50000   2797.500000  19143.000000     8.337331  5.760988e+04
# max    507.00000  99999.000000  19154.000000  1683.518683  1.164143e+07
#
#        Shape__Length
# count     507.000000
# mean     1715.844176
# std      6133.419471
# min        57.986107
# 25%       359.003959
# 50%       723.559436
# 75%      1229.773724
# max     91235.145566

# %%
# shape
pparks.shape
# Out:
# (507, 25)

# %%
# column names
pparks.columns
# Out:
# Index(['OBJECTID', 'PUBLIC_NAME', 'PARENT_NAME', 'NESTED', 'OFFICIAL_NAME',
#        'LABEL', 'ALIAS', 'DPP_ASSET_ID', 'ADDRESS_911', 'ZIP_CODE',
#        'ADDRESS_BRT', 'ALIAS_ADDRESS', 'ACREAGE', 'PROPERTY_CLASSIFICATION',
#        'PPR_USE', 'PPR_PROG_DISTRICT', 'PPR_OPS_DISTRICT', 'COUNCIL_DISTRICT',
#        'POLICE_DISTRICT', 'CITY_SCALE_MAPS', 'LOCAL_SCALE_MAPS',
#        'PROGRAM_SITES', 'COMMENTS', 'Shape__Area', 'Shape__Length'],
#       dtype='object')

# %% [markdown]
# **3. explore dataframe**

# %%
# show first 5 rows
pparks.head()
# Out:
#    OBJECTID                                     PUBLIC_NAME  \
# 0         1  William H (Billy) Markward Memorial Playground
# 1         2                                Schuylkill Banks
# 2         3                           Schuylkill River Park
# 3         4                           Frankford Boat Launch
# 4         5                            Robert A Borski Park
#
#              PARENT_NAME NESTED  \
# 0  Schuylkill River Park      Y
# 1       Schuylkill Banks      N
# 2  Schuylkill River Park      N
# 3  Frankford Boat Launch      N
# 4   Robert A Borski Park      N
#
#                                      OFFICIAL_NAME                  LABEL  \
# 0  William H. (Billy) Markward Memorial Playground               Markward
# 1                                              NaN       Schuylkill Banks
# 2                                              NaN  Schuylkill River Park
# 3                            Frankford Boat Launch       Frankford Launch
# ...

# %%
# show las 5 rows
pparks.tail()
# Out:
#      OBJECTID                          PUBLIC_NAME              PARENT_NAME  \
# 502       503                        Fernhill Park            Fernhill Park
# 503       504        School District Area (Gorgas)        Susan Gorgas Park
# 504       505                    Susan Gorgas Park        Susan Gorgas Park
# 505       506  Mann Center for the Performing Arts      West Fairmount Park
# 506       507              45th and Sansom Tot Lot  45th and Sansom Tot Lot
#
#     NESTED                            OFFICIAL_NAME                     LABEL  \
# 502      N                                      NaN                  Fernhill
# 503      Y                                      NaN  Gorgas (School District)
# 504      Y                        Susan Gorgas Park                    Gorgas
# 505      Y  The Mann Center for the Performing Arts               Mann Center
# 506      N                                      NaN           45th and Sansom
#
# ...

# %% [markdown]
# **4. measures of central tendency**

# %%
# mean
meanps = pparks["ACREAGE"].mean()
meanps
# Out:
# 20.00092127211045

# %%
# median
medianps = pparks["ACREAGE"].median() # option 1
medianps = pparks["ACREAGE"].quantile() # option 2
medianps
# Out:
# 3.60078362

# %%
# are they the same?
meanps == medianps
# Out:
# False

# %%
print("The mean park size is " + str(round(meanps,2)) + " and the median is " + str(round(medianps,2)) + ".")
print("The statement that the mean and the median are the same is " + str(meanps == medianps) + "!")
# Out:
# The mean park size is 20.0 and the median is 3.6.
# The statement that the mean and the median are the same is False!

# %% [markdown]
# **Q**: What can you conclude from the values of the mean and median you extracted?
#
#
#  **A**: The mean is much larger than the median. This may point to outlier data that greatly affect the mean (bring it up), but not so much the median (stays consistent). Most parks have a size "near" 4 acres, while a few parks are very big.

# %%
# plot
ax = pparks["ACREAGE"].hist(bins=10) # plot histogram with 10 data bins
ax.set_title("Mean and Median Size of Parks in Philadelphia", weight = 'bold', size = 16) # figure title
ax.set_xlabel("park size in acres") # x-axis title
ax.set_ylabel("number of parks") # y-axis title
ax.axvline(meanps, color = "red") # show mean
ax.axvline(medianps, color = "orange") # show median
ax.legend(["mean", "median"]); # show legend

# %% [markdown]
# **Figure 1**: This figure depicts a histogram of park size in Philadelphia. Park size measured in terms of acres is on the horizontal axis and the number of parks that are of a certain size is on the vertical axis. The mean and median park size are shown by red and orange vertical bars. We can see that the vast majority of parks (~ 500) fall within the range of zero to ~ 200 acres, while bars of minimal height indicate a very small number of parks of much larger size. The mean (= 20.0 acres) and median (= 3.6 acres) lines further highlight this tendency. The mean is further to the right than the median, indicating the presence of outliers (very big parks) that affect the mean but not the median.

# %% [markdown]
# **5. spread of park size**

# %%
stdps = pparks["ACREAGE"].std()
stdps
# Out:
# 111.8438910224896

# %% [markdown]
# **6. select only a subset of the parks: the parks smaller than 10 acres**

# %%
# get subset of data
small_parks = pparks[pparks["ACREAGE"] < 10]
small_parks = small_parks.reset_index(drop=True)
small_parks
# Out:
#      OBJECTID                                     PUBLIC_NAME  \
# 0           1  William H (Billy) Markward Memorial Playground
# 1           3                           Schuylkill River Park
# 2          14                          29th and Passyunk Park
# 3          17                        Whitby Avenue Playground
# 4          18                           Price Street Play Lot
# ..        ...                                             ...
# 395       500                       Lawrence Court Breezeways
# 396       501                     Vine Street Park (676 East)
# 397       502                     Vine Street Park (676 West)
# 398       504                   School District Area (Gorgas)
# 399       507                         45th and Sansom Tot Lot
#
#                    PARENT_NAME NESTED  \
# 0        Schuylkill River Park      Y
# 1        Schuylkill River Park      N
# 2       29th and Passyunk Park      N
# 3             Cobbs Creek Park      Y
# ...

# %% [markdown]
# **7. aggregate parks by parent park**

# %%
pparks.groupby("PARENT_NAME")["ACREAGE"].mean().mean() # group mean
pparks.groupby("PARENT_NAME")["ACREAGE"].mean().median() # group median
# Out:
# 3.0184954

# %%
ax = pparks.groupby("PARENT_NAME")["ACREAGE"].mean().hist(bins = 10)
ax.set_title("Average Size of Parks By Parent Park in Philadelphia", weight = 'bold', size = 16) # figure title
ax.set_xlabel("average park size by parent park in acres") # x-axis title
ax.set_ylabel("number of parent parks"); # y-axis title
ax.axvline(pparks.groupby("PARENT_NAME")["ACREAGE"].mean().mean(), color = "red") # show mean
ax.axvline(pparks.groupby("PARENT_NAME")["ACREAGE"].mean().median(), color = "orange") # show median
ax.legend(["mean", "median"]); # show legend

# %% [markdown]
# **Figure 2**: This figure depicts a histogram of average park size by parent park in Philadelphia. Average size of parks that belong to a certain parent park, measured in terms of acres, is on the horizontal axis and the number of parents parks whose parks are, on average, of a certain size is on the vertical axis. The mean (= 9.33) and median (= 3.02) park size are shown by red and orange vertical bars. We can see that the vast majority of parent parks (~ 355) fall within the range of zero to ~ 25 acres, while bars of minimal height indicate a very small number of parents parks of much larger average size. Like before, the mean and median lines suggest the presence of outliers. The mean is further to the right than the median that affect the mean but not the median. However, averaging individual park size within parent park groups reduced the magnitude of outliers. The scope of the x-axis is much reduced and the mean is now closer to the median compared to figure 1.

# %% [markdown]
# **Q**: What could you measure about this new dataset obtained by grouping the data by PARENT_NAME that would allow you to investigate further the difference in the two dataset?
#
# **A**: I could compute the standard deviation of park size for both datasets. I would expect lower SD for the aggregated dataset as the most extreme values should have been averaged out by smaller values in the same sub-group (parent park). This would add to the caption for figure 2. I could also look at how other variables are different when comparing the two datasets. For example, I could check if certain zip codes may have less access to parks in general and certain parent parks in particular. Maybe some parent parks are more 'desirable' than others in that they may offer amenities, nature education, etc.
